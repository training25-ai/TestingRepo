# %%
import numpy as np
ex = np.array([3,2,5,6,7])
ex
# Out:
# array([3, 2, 5, 6, 7])

# %%
ex*2
# Out:
# array([ 6,  4, 10, 12, 14])

# %%
matrix = np.array([[4,5,6],[2,6,1]])
matrix*2
# Out:
# array([[ 8, 10, 12],
#        [ 4, 12,  2]])

# %%
import numpy as np
matrix_4x3 = np.array([[2,4,4],
                       [5,3,6],
                       [7,4,5],
                       [6,3,2]])
print(matrix_4x3)
# Out:
# [[2 4 4]
#  [5 3 6]
#  [7 4 5]
#  [6 3 2]]

# %%
print(matrix_4x3*2)
# Out:
# [[ 4  8  8]
#  [10  6 12]
#  [14  8 10]
#  [12  6  4]]

# %%
import postgresql.connector
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import postgresql.connector
#
# ModuleNotFoundError: No module named 'postgresql'

# %%
dbcon = postgresql.connector.connect(
    host = "ep-noisy-lake-a8k78ama-pooler.eastus2.azure.neon.tech",
    user = "abinesh",
    password= "SIT-ML-Playground",
    database = "playground",
    connection_timeout= 60,
    ssl_disabled=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dbcon = postgresql.connector.connect(
#       2     host = "ep-noisy-lake-a8k78ama-pooler.eastus2.azure.neon.tech",
#       3     user = "abinesh",
#       4     password= "SIT-ML-Playground",
#       5     database = "playground",
#       6     connection_timeout= 60,
#       7     ssl_disabled=False)
#
# NameError: name 'postgresql' is not defined

# %%
#cur = dbcon.cursor()
#cur.execute(select *
